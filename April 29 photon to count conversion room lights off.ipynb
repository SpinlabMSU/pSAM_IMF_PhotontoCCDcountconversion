# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from astropy.io import fits

# %%
# opening each file

# AC film dark
#frame = fits.open('Background No Laser 2023 August 28 16_45_33.fits') # 100ms exposure after continuous data
#ac_filmdark_100ms = np.array(frame[0].data,dtype=np.float64)
frame1bg = fits.open('2024 April 29 17_21_08_lightsoff_background_1.fits')
frame2bg = fits.open('2024 April 29 17_23_38_lightsoff_background_2.fits')
frame3bg = fits.open('2024 April 29 17_26_36_lightsoff_background_3.fits') # 100ms exposure after continuous data
frame4bg = fits.open('2024 April 29 17_28_15_lightsoff_background_4.fits') # 100ms exposure after continuous data
frame5bg = fits.open('2024 April 29 17_30_10_lightsoff_background_5.fits')
frame6bg = fits.open('2024 April 29 17_31_40_lightsoff_background_6.fits')
frame7bg = fits.open('2024 April 29 17_33_08_lightsoff_background_7.fits')
frame8bg = fits.open('2024 April 29 17_34_38_lightsoff_background_8.fits')
frame9bg = fits.open('2024 April 29 17_36_45_lightsoff_background_9.fits')
frame10bg = fits.open('2024 April 29 17_38_31_lightsoff_background_10.fits')

ac_filmdark1_800ms = np.array(frame1bg[0].data,dtype=np.float64)
ac_filmdark2_800ms = np.array(frame2bg[0].data,dtype=np.float64)
ac_filmdark3_800ms = np.array(frame3bg[0].data,dtype=np.float64)
ac_filmdark4_800ms = np.array(frame4bg[0].data,dtype=np.float64)
ac_filmdark5_800ms = np.array(frame5bg[0].data,dtype=np.float64)
ac_filmdark6_800ms = np.array(frame6bg[0].data,dtype=np.float64)
ac_filmdark7_800ms = np.array(frame7bg[0].data,dtype=np.float64)
ac_filmdark8_800ms = np.array(frame8bg[0].data,dtype=np.float64)
ac_filmdark9_800ms = np.array(frame9bg[0].data,dtype=np.float64)
ac_filmdark10_800ms = np.array(frame10bg[0].data,dtype=np.float64)

frame1bg.close
frame2bg.close
frame3bg.close
frame4bg.close
frame5bg.close
frame6bg.close
frame7bg.close
frame8bg.close
frame9bg.close
frame10bg.close

# AC film signal
frame1 = fits.open('2024 April 29 17_22_03_lightsoff_1.fits')
frame2 = fits.open('2024 April 29 17_24_31_lightsoff_2.fits')
frame3 = fits.open('2024 April 29 17_27_02_lightsoff_3.fits') # 100ms exposure after continuous data
frame4 = fits.open('2024 April 29 17_28_49_lightsoff_4.fits') # 100ms exposure after continuous data
frame5 = fits.open('2024 April 29 17_30_32_lightsoff_5.fits')
frame6 = fits.open('2024 April 29 17_32_02_lightsoff_6.fits')
frame7 = fits.open('2024 April 29 17_33_29_lightsoff_7.fits')
frame8 = fits.open('2024 April 29 17_35_33_lightsoff_8.fits')
frame9 = fits.open('2024 April 29 17_37_10_lightsoff_9.fits')
frame10 = fits.open('2024 April 29 17_39_20_lightsoff_10.fits')


ac_filmsignal1= np.array(frame1[0].data,dtype=np.float64)
ac_filmsignal2= np.array(frame2[0].data,dtype=np.float64)
ac_filmsignal3= np.array(frame3[0].data,dtype=np.float64)
ac_filmsignal4= np.array(frame4[0].data,dtype=np.float64)
ac_filmsignal5= np.array(frame5[0].data,dtype=np.float64)
ac_filmsignal6= np.array(frame6[0].data,dtype=np.float64)
ac_filmsignal7= np.array(frame7[0].data,dtype=np.float64)
ac_filmsignal8= np.array(frame8[0].data,dtype=np.float64)
ac_filmsignal9= np.array(frame9[0].data,dtype=np.float64)
ac_filmsignal10= np.array(frame10[0].data,dtype=np.float64)
frame1.close
frame2.close
frame3.close
frame4.close
frame5.close
frame6.close
frame7.close
frame8.close
frame9.close
frame10.close


# bias frames
#frame = fits.open('220627_Kr_34K_bias_nofilm_wls_off.fits') # 1ms exposure bias frame
#bias_nofilm_1ms = np.array(frame[0].data,dtype=np.float64)
#frame.close

print("Shape of the arrays: {}".format(ac_filmsignal1.shape)) # checking the size of an array
# Out:
# Shape of the arrays: (1, 1024, 1024)

# %%
# reshaping the array by removing the "1" of a 3D array
#---------------------------------------------------------------------------------
# with film dark files 
ac_filmdark1_800ms = ac_filmdark1_800ms.reshape([1024,1024])
ac_filmdark2_800ms = ac_filmdark2_800ms.reshape([1024,1024])
ac_filmdark3_800ms = ac_filmdark3_800ms.reshape([1024,1024])
ac_filmdark4_800ms = ac_filmdark4_800ms.reshape([1024,1024])
ac_filmdark5_800ms = ac_filmdark5_800ms.reshape([1024,1024])
ac_filmdark6_800ms = ac_filmdark6_800ms.reshape([1024,1024])
ac_filmdark7_800ms = ac_filmdark7_800ms.reshape([1024,1024])
ac_filmdark8_800ms = ac_filmdark8_800ms.reshape([1024,1024])
ac_filmdark9_800ms = ac_filmdark9_800ms.reshape([1024,1024])
ac_filmdark10_800ms = ac_filmdark10_800ms.reshape([1024,1024])

# --------------------------------------------------------------------------------
# with film signal 
ac_filmsignal1 = ac_filmsignal1.reshape([1024,1024])
ac_filmsignal2 = ac_filmsignal2.reshape([1024,1024])
ac_filmsignal3 = ac_filmsignal3.reshape([1024,1024])
ac_filmsignal4 = ac_filmsignal4.reshape([1024,1024])
ac_filmsignal5 = ac_filmsignal5.reshape([1024,1024])
ac_filmsignal6 = ac_filmsignal6.reshape([1024,1024])
ac_filmsignal7 = ac_filmsignal7.reshape([1024,1024])
ac_filmsignal8 = ac_filmsignal8.reshape([1024,1024])
ac_filmsignal9 = ac_filmsignal9.reshape([1024,1024])
ac_filmsignal10 = ac_filmsignal10.reshape([1024,1024])

# ---------------------------------------------------------------------------------
# bias frames 
#bias_nofilm_1ms = bias_nofilm_1ms.reshape([1040,1392])

# ---------------------------------------------------------------------------------
print("Dimensions of the arrays: {}".format(ac_filmsignal1.shape))# confirming the dimensions of each array
# Out:
# Dimensions of the arrays: (1024, 1024)

# %%
# 800ms exposure

# defining exposure time from FITS file(look up referring chart from file to python)
hdul = fits.open('2024 April 29 17_21_08_lightsoff_background_1.fits')  # open a FITS file
hdr = hdul[0].header  # the primary HDU header
exposure = hdr['EXPTIME']



# cutting the dark from the signal
ac_film_subdark1 = ac_filmsignal1 - ac_filmdark1_800ms 
ac_film_subdark2 = ac_filmsignal2 - ac_filmdark2_800ms 
ac_film_subdark3 = ac_filmsignal3 - ac_filmdark3_800ms 
ac_film_subdark4 = ac_filmsignal4 - ac_filmdark4_800ms 
ac_film_subdark5 = ac_filmsignal5 - ac_filmdark5_800ms 
ac_film_subdark6 = ac_filmsignal6 - ac_filmdark6_800ms 
ac_film_subdark7 = ac_filmsignal7 - ac_filmdark7_800ms 
ac_film_subdark8 = ac_filmsignal8 - ac_filmdark8_800ms 
ac_film_subdark9 = ac_filmsignal9 - ac_filmdark9_800ms 
ac_film_subdark10 = ac_filmsignal10 - ac_filmdark10_800ms 


# finding the count rate and converting into seconds
count_rate1= (((ac_film_subdark1)*1.25))
count_rate2 = (((ac_film_subdark2)*1.25))
count_rate3 = (((ac_film_subdark3)*1.25))
count_rate4 = (((ac_film_subdark4)*1.25))
count_rate5 = (((ac_film_subdark5)*1.25))
count_rate6 = (((ac_film_subdark6)*1.25))
count_rate7 = (((ac_film_subdark7)*1.25))
count_rate8 = (((ac_film_subdark8)*1.25))
count_rate9 = (((ac_film_subdark9)*1.25))
count_rate10 = (((ac_film_subdark10)*1.25))

count_rates=np.array([np.sum(count_rate1), np.sum(count_rate2), np.sum(count_rate3), np.sum(count_rate4), np.sum(count_rate5),
            np.sum(count_rate6), np.sum(count_rate7),np.sum(count_rate8), np.sum(count_rate9), np.sum(count_rate10)])

# showing the results
#print("Exposure time is: ", exposure)
print("Shape of the count rate array: {}".format(count_rate10.shape)) # checking the size of an array)\
#print("Count rate is: ", count_rate10)
print(np.sum(count_rate1))
print(np.sum(count_rate2))
print(np.sum(count_rate3))
print(count_rates)
#print(sum(count_rate))
# Out:
# Shape of the count rate array: (1024, 1024)
# 69771514320.0
# 69859931525.0
# 69696426752.5
# [6.97715143e+10 6.98599315e+10 6.96964268e+10 6.97605493e+10
#  6.98974302e+10 6.97571304e+10 6.97056238e+10 6.98970993e+10
#  6.97718023e+10 6.97895005e+10]

# %%
# formatting the density plot with a color map

# setting the max/min values
vmax5 = np.max(count_rate9)
vmin5 = np.min(count_rate9)
# ---------------------------------------------------------------------------
# plotting the transmission data and displaying both variations as one figure
plt.figure(figsize=(20, 10)) # left plot
plt.plot(1, 2, 1)
plt.imshow(count_rate9, vmin=vmin5, vmax=vmax5)
plt.colorbar(shrink=0.75)
plt.ylim(0,1040)
plt.ylabel("Y position")
plt.xlabel("X position")
plt.title("AC Film Appearance (800ms Exposure)")
# Out:
# Text(0.5, 1.0, 'AC Film Appearance (800ms Exposure)')

# %%
count_rate1[753][579]
# Out:
# 66580.0

# %%
#finding the photon rate

power = 7.0E-7 # Watts
wavelength = 9.23E-7 #meters
h = 6.63E-34 #plancks constant J*s
c = 2.99792458E8 #speed of light in m/s


photon_number = (power*wavelength/(h*c))
print(photon_number)
# Out:
# 3250614810068.2656

# %%
gamma_factor_tot = 0
num = 0

mean = np.mean(photon_number/count_rates)
stdev = np.std(photon_number/count_rates)

for count_rate in count_rates:
    gamma_factor = photon_number/count_rate
    print(gamma_factor)
    gamma_factor_tot += gamma_factor
    num += 1

gamma_factor_avg = gamma_factor_tot / num
print("Overall average:", gamma_factor_avg)
print("No geometry:", gamma_factor_avg*(176.89/70.882)/9)
print("mean:",mean/9)
print("stdev:",stdev)
print(176.89/70.882)
# Out:
# 46.58942609672551
# 46.53046086804428
# 46.63961929657558
# 46.59674905735414
# 46.50549814621729
# 46.59903283702901
# 46.63346562004277
# 46.50571828803035
# 46.589233818476735
# 46.57741906486718
# Overall average: 46.57666230933628
# No geometry: 12.914963203161582
# mean: 5.175184701037364
# stdev: 0.045439642981774615
# 2.4955559944696817
